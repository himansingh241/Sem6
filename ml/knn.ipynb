# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
species = ['setosa', 'versicolor', 'virginica']
colours = ['red', 'orange', 'blue']
for i in range(0, 3):    
    species_df = df[df['target'] == i]    
    plt.scatter(        
        species_df['sepal length (cm)'],        
        species_df['petal length (cm)'],
        color=colours[i],        
        alpha=0.5,        
        label=species[i]   
    )
plt.xlabel('Sepal Length')
plt.ylabel('petal length (cm)')
plt.title('petal length vs sepal length')
plt.legend(loc='lower right')
plt.show()

# %%
species = ['setosa', 'versicolor', 'virginica']
colours = ['red', 'orange', 'blue']
for i in range(0, 3):    
    species_df = df[df['target'] == i]    
    plt.scatter(        
        species_df['sepal width (cm)'],        
        species_df['petal width (cm)'],
        color=colours[i],        
        alpha=0.5,        
        label=species[i]   
    )
plt.xlabel('Sepal width')
plt.ylabel('petal width (cm)')
plt.title('petal width vs sepal width')
plt.legend(loc='lower right')
plt.show()

# %%
import seaborn as sns
sns.pairplot(df, hue='target')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
X_test
# Out:
# array([[0.66666667, 0.36363636, 0.55357143, 0.54166667],
#        [0.6969697 , 0.13636364, 0.80357143, 0.70833333],
#        [0.63636364, 0.45454545, 0.67857143, 0.79166667],
#        [0.39393939, 0.72727273, 0.07142857, 0.08333333],
#        [0.96969697, 0.36363636, 0.94642857, 0.83333333],
#        [0.15151515, 0.09090909, 0.35714286, 0.375     ],
#        [0.57575758, 0.31818182, 0.76785714, 0.70833333],
#        [0.15151515, 0.13636364, 0.57142857, 0.66666667],
#        [0.3030303 , 0.54545455, 0.07142857, 0.04166667],
#        [0.54545455, 0.31818182, 0.53571429, 0.5       ],
#        [0.72727273, 0.27272727, 0.625     , 0.54166667],
#        [0.15151515, 0.63636364, 0.01785714, 0.        ],
#        [0.51515152, 0.27272727, 0.48214286, 0.5       ],
#        [0.15151515, 0.36363636, 0.01785714, 0.04166667],
#        [0.33333333, 0.09090909, 0.44642857, 0.41666667],
#        [0.57575758, 0.54545455, 0.76785714, 0.95833333],
#        [0.39393939, 0.27272727, 0.5       , 0.5       ],
#        [0.6969697 , 0.40909091, 0.55357143, 0.54166667],
#        [0.3030303 , 0.77272727, 0.07142857, 0.125     ],
#        [0.60606061, 0.31818182, 0.53571429, 0.5       ],
#        [0.09090909, 0.45454545, 0.05357143, 0.04166667],
#        [0.6969697 , 0.36363636, 0.66071429, 0.66666667],
#        [1.        , 0.36363636, 0.85714286, 0.91666667],
#        [0.12121212, 0.36363636, 0.01785714, 0.08333333],
#        [0.12121212, 0.36363636, 0.01785714, 0.        ],
#        [0.18181818, 0.63636364, 0.01785714, 0.04166667],
#        [0.63636364, 0.36363636, 0.69642857, 0.79166667],
#        [0.84848485, 0.63636364, 0.85714286, 1.        ],
#        [0.        , 0.45454545, 0.        , 0.04166667],
#        [0.60606061, 0.45454545, 0.57142857, 0.58333333],
#        [0.78787879, 0.45454545, 0.60714286, 0.54166667],
#        [0.18181818, 0.59090909, 0.05357143, 0.20833333],
#        [1.        , 0.27272727, 0.96428571, 0.79166667],
#        [1.        , 0.18181818, 1.        , 0.91666667],
#        [0.03030303, 0.04545455, 0.        , 0.08333333],
#        [0.36363636, 0.22727273, 0.51785714, 0.5       ],
#        [0.21212121, 0.13636364, 0.30357143, 0.41666667],
#        [0.21212121, 0.54545455, 0.03571429, 0.04166667],
#        [0.06060606, 0.40909091, 0.03571429, 0.04166667],
#        [0.72727273, 0.45454545, 0.82142857, 0.91666667],
#        [0.42424242, 0.22727273, 0.46428571, 0.45833333],
#        [0.51515152, 0.36363636, 0.58928571, 0.54166667],
#        [0.3030303 , 0.36363636, 0.57142857, 0.58333333],
#        [0.63636364, 0.27272727, 0.58928571, 0.58333333],
#        [0.6969697 , 0.36363636, 0.69642857, 0.91666667],
#        [0.60606061, 0.45454545, 0.71428571, 0.91666667],
#        [0.33333333, 0.13636364, 0.48214286, 0.5       ],
#        [0.42424242, 0.27272727, 0.67857143, 0.95833333],
#        [0.57575758, 0.22727273, 0.64285714, 0.70833333],
#        [0.45454545, 0.45454545, 0.625     , 0.70833333],
#        [0.54545455, 0.        , 0.57142857, 0.58333333],
#        [0.60606061, 0.27272727, 0.76785714, 0.83333333],
#        [0.84848485, 0.45454545, 0.83928571, 0.70833333],
#        [0.39393939, 1.        , 0.03571429, 0.125     ],
#        [0.3030303 , 0.77272727, 0.        , 0.125     ],
#        [0.12121212, 0.54545455, 0.10714286, 0.04166667],
#        [0.6969697 , 0.5       , 0.78571429, 0.83333333],
#        [0.36363636, 0.31818182, 0.41071429, 0.5       ],
#        [0.24242424, 0.22727273, 0.46428571, 0.54166667],
#        [0.57575758, 0.5       , 0.83928571, 1.        ]])

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
# arr=range(1,30)
# arr2=[]
# for i in range(1,30):
#     model = KNeighborsClassifier(n_neighbors=i, metric='manhattan')
#     model.fit(X_train, y_train)
#     y_pred = model.predict(X_test)
#     arr2.append(metrics.accuracy_score(y_test, y_pred))
model = KNeighborsClassifier(n_neighbors=i, metric='manhattan')
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[17,  0,  0],
#        [ 0, 22,  1],
#        [ 0,  1, 19]], dtype=int64)

# %%
plt.scatter(arr,arr2)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/edwindj/datacleaning/master/data/dirty_iris.csv')
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 0           6.4          3.2           4.5          1.5  versicolor
# 1           6.3          3.3           6.0          2.5   virginica
# 2           6.2          NaN           5.4          2.3   virginica
# 3           5.0          3.4           1.6          0.4      setosa
# 4           5.7          2.6           3.5          1.0  versicolor
