# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
species = ['setosa', 'versicolor', 'virginica']
colours = ['red', 'orange', 'blue']
for i in range(0, 3):    
    species_df = df[df['target'] == i]    
    plt.scatter(        
        species_df['sepal length (cm)'],        
        species_df['petal length (cm)'],
        color=colours[i],        
        alpha=0.5,        
        label=species[i]   
    )
plt.xlabel('Sepal Length')
plt.ylabel('petal length (cm)')
plt.title('petal length vs sepal length')
plt.legend(loc='lower right')
plt.show()

# %%
species = ['setosa', 'versicolor', 'virginica']
colours = ['red', 'orange', 'blue']
for i in range(0, 3):    
    species_df = df[df['target'] == i]    
    plt.scatter(        
        species_df['sepal width (cm)'],        
        species_df['petal width (cm)'],
        color=colours[i],        
        alpha=0.5,        
        label=species[i]   
    )
plt.xlabel('Sepal width')
plt.ylabel('petal width (cm)')
plt.title('petal width vs sepal width')
plt.legend(loc='lower right')
plt.show()

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
X_test
# Out:
# array([[0.85294118, 0.6       , 0.87719298, 0.73913043],
#        [0.64705882, 0.5       , 0.84210526, 0.91304348],
#        [0.61764706, 0.55      , 0.78947368, 0.73913043],
#        [0.61764706, 0.35      , 0.75438596, 0.7826087 ],
#        [0.11764706, 0.6       , 0.10526316, 0.04347826],
#        [0.20588235, 0.5       , 0.10526316, 0.04347826],
#        [0.23529412, 0.25      , 0.35087719, 0.43478261],
#        [0.52941176, 0.4       , 0.52631579, 0.52173913],
#        [0.17647059, 0.8       , 0.07017544, 0.        ],
#        [0.08823529, 0.8       , 0.        , 0.04347826],
#        [0.61764706, 0.6       , 0.61403509, 0.60869565],
#        [0.88235294, 0.45      , 0.92982456, 0.73913043],
#        [0.20588235, 0.6       , 0.03508772, 0.04347826],
#        [0.17647059, 0.55      , 0.0877193 , 0.04347826],
#        [0.38235294, 0.45      , 0.45614035, 0.52173913],
#        [0.76470588, 0.55      , 0.77192982, 0.86956522],
#        [0.73529412, 0.4       , 0.66666667, 0.56521739],
#        [0.20588235, 0.7       , 0.0877193 , 0.04347826],
#        [0.05882353, 0.15      , 0.05263158, 0.08695652],
#        [0.20588235, 0.7       , 0.10526316, 0.13043478],
#        [0.11764706, 0.6       , 0.05263158, 0.04347826],
#        [0.76470588, 0.6       , 0.8245614 , 0.95652174],
#        [0.58823529, 0.7       , 0.80701754, 1.        ],
#        [0.44117647, 0.35      , 0.54385965, 0.39130435],
#        [0.17647059, 0.25      , 0.61403509, 0.69565217],
#        [0.20588235, 0.65      , 0.07017544, 0.04347826],
#        [0.44117647, 1.        , 0.03508772, 0.04347826],
#        [0.35294118, 0.25      , 0.52631579, 0.52173913],
#        [0.47058824, 0.5       , 0.56140351, 0.60869565],
#        [0.02941176, 0.45      , 0.07017544, 0.04347826],
#        [0.38235294, 0.4       , 0.68421053, 0.82608696],
#        [0.44117647, 0.4       , 0.71929825, 1.        ],
#        [0.52941176, 0.4       , 0.64912281, 0.47826087],
#        [0.47058824, 0.5       , 0.71929825, 0.73913043],
#        [0.17647059, 0.2       , 0.40350877, 0.39130435],
#        [0.5       , 0.7       , 0.61403509, 0.65217391],
#        [0.5       , 0.5       , 0.66666667, 0.73913043],
#        [0.64705882, 0.6       , 0.71929825, 0.82608696],
#        [0.        , 0.5       , 0.01754386, 0.        ],
#        [0.41176471, 0.5       , 0.56140351, 0.47826087],
#        [0.58823529, 0.35      , 0.68421053, 0.73913043],
#        [0.5       , 0.1       , 0.52631579, 0.39130435],
#        [0.61764706, 0.4       , 0.80701754, 0.91304348],
#        [0.23529412, 0.65      , 0.12280702, 0.17391304],
#        [0.08823529, 0.6       , 0.07017544, 0.04347826],
#        [0.58823529, 0.4       , 0.71929825, 0.60869565],
#        [0.64705882, 0.5       , 0.73684211, 0.82608696],
#        [1.        , 0.4       , 1.        , 0.82608696],
#        [0.41176471, 0.4       , 0.54385965, 0.52173913],
#        [0.67647059, 0.5       , 0.59649123, 0.56521739],
#        [0.76470588, 0.55      , 0.71929825, 0.95652174],
#        [1.        , 0.9       , 1.        , 0.91304348],
#        [0.73529412, 0.5       , 0.78947368, 0.86956522],
#        [0.08823529, 0.55      , 0.0877193 , 0.04347826],
#        [0.35294118, 0.2       , 0.47368421, 0.39130435],
#        [0.70588235, 0.55      , 0.59649123, 0.56521739],
#        [0.20588235, 0.        , 0.43859649, 0.39130435],
#        [0.23529412, 0.9       , 0.0877193 , 0.08695652],
#        [0.70588235, 0.5       , 0.73684211, 0.95652174],
#        [0.55882353, 0.45      , 0.57894737, 0.52173913]])

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred
# Out:
# array([2, 2, 2, 2, 0, 0, 1, 1, 0, 0, 1, 2, 0, 0, 1, 2, 1, 0, 0, 0, 0, 2,
#        2, 1, 1, 0, 0, 1, 1, 0, 2, 2, 1, 2, 1, 2, 2, 2, 0, 1, 2, 1, 2, 0,
#        0, 2, 2, 2, 1, 1, 2, 2, 2, 0, 1, 1, 1, 0, 2, 1])

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9666666666666667

# %%
from sklearn.preprocessing import normalize
